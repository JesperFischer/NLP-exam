# %%
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem import PorterStemmer
from utility_funtions import *
from nltk.stem.porter import *
import numpy as np
import nltk

datacon = abstracter(1000,"Consciousness","journal,abstract,title,year")
datacon = cleaner(datacon,year = 1990)

dataana = abstracter(1000,"Anesthesiology","journal,abstract,title,year","medicine")
dataana = cleaner(dataana,year = 1990)

datanlp = abstracter(1000,"Natural+Language+Processing","journal,abstract,title,year")
datanlp = cleaner(datanlp,year = 1990)
data = pd.concat([datacon,dataana,datanlp])
# Out:
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>
# <Response [200]>

# %%
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package omw-1.4 to /home/jespere/nltk_data...
# True

# %%
nltk.download('wordnet')
from nltk.corpus import stopwords

def lemmatize_stemming(text):
    lemmatized = WordNetLemmatizer().lemmatize(text, pos='v')
    return PorterStemmer().stem(lemmatized)


def preprocess(text):
    result = []
    #gensim does tokenization and makes everything lowercase.
    for token in gensim.utils.simple_preprocess(text):
        #want to remove the stopwords and tokens that have fewer than 3 characters
        if token not in stopwords.words("english") and len(token) > 3:
            #append the resulting tokens after being lemmatized and stemmed
            result.append(lemmatize_stemming(token))
    return result
# Out:
# [nltk_data] Downloading package wordnet to /home/jespere/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
processed_docs = data["abstracts"].map(preprocess)

dictionary = gensim.corpora.Dictionary(processed_docs)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]

# %%
dictionary = gensim.corpora.Dictionary(processed_docs)
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
# Out:
# [(6, 1),
#  (7, 5),
#  (16, 2),
#  (59, 1),
#  (87, 1),
#  (97, 2),
#  (132, 2),
#  (133, 1),
#  (134, 1),
#  (135, 1),
#  (136, 2),
#  (137, 1),
#  (138, 4),
#  (139, 1),
#  (140, 4),
#  (141, 1),
#  (142, 1),
#  (143, 3),
#  (144, 1),
#  (145, 1),
#  (146, 4),
#  (147, 1),
#  (148, 1),
#  (149, 1),
#  (150, 1),
#  (151, 1),
#  (152, 4),
#  (153, 1),
#  (154, 1),
#  (155, 1),
#  (156, 1),
#  (157, 1),
#  (158, 1),
#  (159, 1),
#  (160, 1),
#  (161, 1),
#  (162, 1),
#  (163, 4),
#  (164, 5),
#  (165, 1),
#  (166, 1),
#  (167, 1),
#  (168, 1),
#  (169, 1),
#  (170, 1),
#  (171, 2),
#  (172, 1),
#  (173, 1),
#  (174, 1),
#  (175, 3),
#  (176, 3),
#  (177, 1),
#  (178, 1),
#  (179, 1)]

# %%
#tf-idf
from gensim import corpora, models
tfidf = models.TfidfModel(bow_corpus)
corpus_tfidf = tfidf[bow_corpus]
from pprint import pprint
for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.22813279792700364),
#  (1, 0.10619059974292071),
#  (2, 0.2794983106024311),
#  (3, 0.09321513366020322),
#  (4, 0.0894661683864069),
#  (5, 0.13676126741720238),
#  (6, 0.09522652345779807),
#  (7, 0.050105180767623866),
#  (8, 0.14436312974677795),
#  (9, 0.23445325031721337),
#  (10, 0.2828663699334322),
#  (11, 0.13760202436976743),
#  (12, 0.13804267735656822),
#  (13, 0.19175178678927324),
#  (14, 0.2887262594935559),
#  (15, 0.18308773764178593),
#  (16, 0.08406585067394426),
#  (17, 0.21782845881735952),
#  (18, 0.15183863826037283),
#  (19, 0.1064909804331817),
#  (20, 0.09591952780008119),
#  (21, 0.15276006537080888),
#  (22, 0.23445325031721337),
#  (23, 0.23445325031721337),
#  (24, 0.2628735191025772),
#  (25, 0.10501061094571322),
#  (26, 0.17278339853214178),
#  (27, 0.09432036987364681),
#  (28, 0.15466746885642207),
#  (29, 0.0459073320586951),
#  (30, 0.17129226035627593),
#  (31, 0.1163242756266175),
#  (32, 0.07405334041787619),
# ...

# %%
lda_model = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.003*"languag" + 0.002*"conscious" + 0.002*"simul" + 0.002*"system" + 0.002*"natur" + 0.002*"train" + 0.002*"resid" + 0.002*"process" + 0.002*"model" + 0.001*"inform"
# Topic: 1
# Words: 0.003*"conscious" + 0.002*"self" + 0.002*"brand" + 0.002*"languag" + 0.002*"patient" + 0.001*"resid" + 0.001*"social" + 0.001*"process" + 0.001*"consciou" + 0.001*"natur"
# Topic: 2
# Words: 0.003*"languag" + 0.003*"resid" + 0.002*"model" + 0.002*"learn" + 0.002*"conscious" + 0.002*"research" + 0.002*"process" + 0.002*"train" + 0.002*"program" + 0.002*"natur"
# Topic: 3
# Words: 0.002*"conscious" + 0.002*"languag" + 0.001*"natur" + 0.001*"model" + 0.001*"patient" + 0.001*"process" + 0.001*"sentenc" + 0.001*"task" + 0.001*"anesthesiolog" + 0.001*"semant"
# Topic: 4
# Words: 0.002*"conscious" + 0.002*"languag" + 0.002*"part" + 0.001*"self" + 0.001*"care" + 0.001*"patient" + 0.001*"model" + 0.001*"anesthesiolog" + 0.001*"anesthesia" + 0.001*"task"
# Topic: 5
# ...

# %%
topic_weights = []
for row_list in lda_model[bow_corpus]:
    weight_list = []
    for i, w in row_list:
        weight_list.append(w)
    topic_weights.append(weight_list)

# %%
import seaborn as sns
import matplotlib.colors as mcolors

arr = pd.DataFrame(topic_weights).fillna(0).values

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)

# tSNE Dimension Reduction
tsne_model = TSNE(n_components=2, verbose=1, random_state=0, angle=.99, init='pca')
tsne_lda = tsne_model.fit_transform(arr)

# Plot the Topic Clusters using Bokeh
output_notebook()
n_topics = 3
mycolors = np.array([color for name, color in mcolors.TABLEAU_COLORS.items()])
plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=900, plot_height=700)
plot.scatter(x=tsne_lda[:,0], y=tsne_lda[:,1], color=mycolors[topic_num])
show(plot)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 1769 samples in 0.002s...
# [t-SNE] Computed neighbors for 1769 samples in 0.041s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 1769
# [t-SNE] Computed conditional probabilities for sample 1769 / 1769
# [t-SNE] Mean sigma: 0.001813
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 57.049900
# [t-SNE] KL divergence after 1000 iterations: 0.455524
# /home/jespere/.local/lib/python3.9/site-packages/bokeh/io/notebook.py:487: DeprecationWarning:
#
# The `source` parameter emit a  deprecation warning since IPython 8.0, it had no effects for a long time and will  be removed in future versions.
# <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1601">Loading BokehJS ...</span>
#     </div>
# /home/jespere/.local/lib/python3.9/site-packages/bokeh/io/notebook.py:487: DeprecationWarning:
#
# ...

# %%
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook


umapp = umap.UMAP(n_components=2)
proj = umapp.fit_transform(arr)
    
x =proj[:,0]
y =proj[:,1]

plot = figure(title="t-SNE Clustering of {} LDA Topics".format(n_topics), 
              plot_width=900, plot_height=700)
              
plot.scatter(x=x, y=y)
show(plot)
# Out:
# /home/jespere/.local/lib/python3.9/site-packages/bokeh/io/notebook.py:487: DeprecationWarning:
#
# The `source` parameter emit a  deprecation warning since IPython 8.0, it had no effects for a long time and will  be removed in future versions.
#   <div class="bk-root" id="94c6a471-96ec-4080-bbbd-6b2c8ee99c4f" data-root-id="1751"></div>
# /home/jespere/.local/lib/python3.9/site-packages/bokeh/io/notebook.py:487: DeprecationWarning:
#
# The `source` parameter emit a  deprecation warning since IPython 8.0, it had no effects for a long time and will  be removed in future versions.

# %%
from sklearn.manifold import TSNE
from bokeh.plotting import figure, output_file, show
from bokeh.models import Label
from bokeh.io import output_notebook

# Get topic weights
topic_weights = []
for i, row_list in enumerate(lda_model[bow_corpus]):
    topic_weights.append([w for i, w in row_list[0]])

# Array of topic weights    
arr = pd.DataFrame(topic_weights).fillna(0).values

# Keep the well separated points (optional)
arr = arr[np.amax(arr, axis=1) > 0.35]

# Dominant topic number in each doc
topic_num = np.argmax(arr, axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/jespere/NLP/NLP-exam/LDA.ipynb Cell 17 in <module>
#       <a href='vscode-notebook-cell://ssh-remote%2B77.33.154.147/home/jespere/NLP/NLP-exam/LDA.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> topic_weights = []
#       <a href='vscode-notebook-cell://ssh-remote%2B77.33.154.147/home/jespere/NLP/NLP-exam/LDA.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> for i, row_list in enumerate(lda_model[bow_corpus]):
# ----> <a href='vscode-notebook-cell://ssh-remote%2B77.33.154.147/home/jespere/NLP/NLP-exam/LDA.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     topic_weights.append([w for i, w in row_list[0]])
#      <a href='vscode-notebook-cell://ssh-remote%2B77.33.154.147/home/jespere/NLP/NLP-exam/LDA.ipynb#X41sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> # Array of topic weights
# ...

# %%
import pyLDAvis
import pyLDAvis.gensim_models



pyLDAvis.enable_notebook()
vis = pyLDAvis.gensim_models.prepare(lda_model, corpus_tfidf, dictionary=lda_model.id2word)
vis
# Out:
# /usr/lib/python3/dist-packages/past/types/oldstr.py:23: DeprecationWarning: invalid escape sequence \d
#   """
# /usr/lib/python3/dist-packages/past/builtins/misc.py:45: DeprecationWarning: the imp module is deprecated in favour of importlib; see the module's documentation for alternative uses
#   from imp import reload
# PreparedData(topic_coordinates=              x         y  topics  cluster       Freq
# topic
# 2      0.023834 -0.008322       1        1  16.419612
# 0      0.024584 -0.013335       2        1  14.738055
# 8      0.016666  0.014551       3        1  12.655493
# 6      0.008412  0.014707       4        1  11.052619
# 5     -0.010848  0.020300       5        1   9.676060
# 7     -0.008928  0.003746       6        1   8.591627
# 4      0.000463 -0.011574       7        1   8.445509
# 1     -0.016169  0.002724       8        1   6.808081
# 9     -0.017812  0.001039       9        1   6.267239
# ...
